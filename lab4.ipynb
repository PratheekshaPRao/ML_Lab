# %% [markdown]
# <a href="https://colab.research.google.com/github/PratheekshaPRao/ML_Lab/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('studentData2.csv')
attribute=np.array(data)[:,:-1]
target=np.array(data)[:,-1]
print("student data:\n")
print(data)
def train(att,tar):
  for i,val in enumerate(tar):
    if val=='yes':
      specific_h=att[i].copy()
      break
  for i,val in enumerate(att):
      if tar[i]=='yes':
        for x in range(len(specific_h)):
          if val[x]!=specific_h[x]:
            specific_h[x]='?'
          else:
            pass
  return specific_h
print("\n")
print(train(attribute,target))
# Out:
# student data:
#
#    >=9  yes        good good.1  fast yes.1 yes.2
# 0  >=9  yes  excellence   good  fast   yes   yes
# 1  >=8   no        good   good  fast    no    no
# 2  >=9  yes        good   good  slow    no   yes
#
#
# ['>=9' 'yes' '?' 'good' '?' '?']
